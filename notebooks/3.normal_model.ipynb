# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

import mlflow

# %%
MLFLOW_PATH = "http://localhost:5001/"
mlflow.set_tracking_uri(MLFLOW_PATH)

# %%
import mlflow
logged_model = 'runs:/4bbca3f2aabd45229479b5d8f7e94664/model'

# Load model as a PyFuncModel.
loaded_model = mlflow.sklearn.load_model(logged_model)

# %%
loaded_model
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['customer_age', 'tenure',
#                                                    'account_balance',
#                                                    'previous_campaign_number_of_contacts']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value='missing',
# ...

# %%
data = pd.read_excel(r"C:\Users\admin\Documents\Projects\MLE\data\bank.xlsx")

# %%
data
# Out:
#        CIF       date  customer_age  tenure employment_type marital_status  \
# 0        0 2024-03-31            30     4.5      unemployed        married
# 1        1 2024-03-31            33    12.5        services        married
# 2        2 2024-03-31            35    10.2      management         single
# 3        3 2024-03-31            30     7.2      management        married
# 4        4 2024-03-31            59     4.7     blue-collar        married
# ...    ...        ...           ...     ...             ...            ...
# 4516  4516 2024-03-31            33     6.9        services        married
# 4517  4517 2024-03-31            57    26.9   self-employed        married
# 4518  4518 2024-03-31            57     5.9      technician        married
# 4519  4519 2024-03-31            28     0.3     blue-collar        married
# 4520  4520 2024-03-31            44    12.9    entrepreneur         single
#
#      education_level credit_default  account_balance housing_loan  \
# ...

# %%
pd.DataFrame(data.iloc[0]).T
# Out:
#   CIF                 date customer_age tenure employment_type marital_status  \
# 0   0  2024-03-31 00:00:00           30    4.5      unemployed        married
#
#   education_level credit_default account_balance housing_loan personal_loan  \
# 0         primary             no            1787           no            no
#
#   contact_method previous_campaign_number_of_contacts  \
# 0       cellular                                    0
#
#   previous_campaign_outcome  y
# 0                   unknown  0

# %%
expected_columns = [
    'customer_age', 
    'tenure', 
    'employment_type', 
    'marital_status', 
    'education_level', 
    'credit_default',
    'account_balance', 
    'housing_loan', 
    'personal_loan', 
    'contact_method', 
    'previous_campaign_number_of_contacts', 
    'previous_campaign_outcome'
]

customer_data = {
        'customer_age': 35,
        'tenure': 5.5,
        'employment_type': 'services',
        'marital_status': 'married',
        'education_level': 'secondary',
        'credit_default': 'no',
        'account_balance': 2500,
        'housing_loan': 'yes',
        'personal_loan': 'no',
        'contact_method': 'cellular',
        'previous_campaign_number_of_contacts': 2,
        'previous_campaign_outcome': 'failure'
    }
# Create DataFrame from input
df = pd.DataFrame([customer_data])
df
# Out:
#    customer_age  tenure employment_type marital_status education_level  \
# 0            35     5.5        services        married       secondary
#
#   credit_default  account_balance housing_loan personal_loan contact_method  \
# 0             no             2500          yes            no       cellular
#
#    previous_campaign_number_of_contacts previous_campaign_outcome
# 0                                     2                   failure

# %%
loaded_model.predict(pd.DataFrame(data.iloc[0]).T)
# Out:
# array([0], dtype=int64)
