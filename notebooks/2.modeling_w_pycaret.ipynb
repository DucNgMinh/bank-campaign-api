# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import pycaret
from pycaret.classification import *
import mlflow

# %%
MLFLOW_PATH = "http://localhost:5001/"

# %%
mlflow.set_tracking_uri(MLFLOW_PATH)
mlflow.autolog()
# Out:
# 2025/04/05 14:30:46 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2025/04/05 14:30:46 WARNING mlflow.utils.autologging_utils: MLflow statsmodels autologging is known to be compatible with 0.11.1 <= statsmodels <= 0.14.2, but the installed version is 0.14.4. If you encounter errors during autologging, try upgrading / downgrading statsmodels to a compatible version, or try upgrading MLflow.
# 2025/04/05 14:30:46 INFO mlflow.tracking.fluent: Autologging successfully enabled for statsmodels.

# %%
mlflow.set_experiment("Certificate of Deposit Campaign")
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/4', creation_time=1743757036931, experiment_id='4', last_update_time=1743757036931, lifecycle_stage='active', name='Certificate of Deposit Campaign', tags={}>

# %%
data = pd.read_excel(r"C:\Users\admin\Documents\Projects\MLE\data\bank.xlsx")

# %%
# Step 4: Setup PyCaret with MLflow integration
print("Setting up PyCaret environment...")
with mlflow.start_run(run_name="model_selection"):
    # Initialize setup
    clf = setup(
        data=data,
        
        target='y',
        session_id=12,
        ignore_features=['CIF', 'date'],  # CIF is likely just an ID number
        
        # Preproceessing Setup
        preprocess= True,
        
        normalize=False,
        normalize_method="zscore",
        
        imputation_type=None,
        numeric_imputation=0,
        categorical_imputation="UNKNOWN",
        
        max_encoding_ohe=10,
        encoding_method=None,
        
        rare_value="OTHER",
        rare_to_value=0.05,
        
        polynomial_features=False,
        polynomial_degree=2,
        
        remove_multicollinearity=False,
        multicollinearity_threshold=0.9,
        
        remove_outliers=False,
        
        fix_imbalance=False,  # Address class imbalance
        pca=False,
        
        feature_selection=False,
        n_features_to_select=0.5,
        
        fold=5,
        fold_strategy="kfold",
        fold_shuffle=True,
        
        n_jobs=4,
        
        log_experiment=False,
        experiment_name="Certificate of Deposit Campaign",
        experiment_custom_tags={
            "Model_Type": "Pycaret Model"
        },
        log_plots=True,
        verbose=False
    )
    
    # Log PyCaret setup details to MLflow only, without permanent local file
    setup_details = pull()
    temp_setup_path = 'temp_pycaret_setup.csv'
    setup_details.to_csv(temp_setup_path)
    mlflow.log_artifact(temp_setup_path)
    os.remove(temp_setup_path)
    
    # Step 5: Compare Models
    print("Comparing different ML models...")
    models_comparison = compare_models()
    
    # Log comparison results to MLflow without local file
    comparison_results = pull()
    temp_comparison_path = 'temp_model_comparison.csv'
    comparison_results.to_csv(temp_comparison_path)
    mlflow.log_artifact(temp_comparison_path)
    os.remove(temp_comparison_path)
# Out:
# Setting up PyCaret environment...
# 2025/04/05 15:06:33 INFO mlflow.tracking._tracking_service.client: 🏃 View run Session Initialized 8990 at: http://localhost:5001/#/experiments/4/runs/036f1d0b830b483dbc16638970783df6.
# 2025/04/05 15:06:33 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5001/#/experiments/4.
# Comparing different ML models...
# <style type="text/css">
# #T_5a343 th {
#   text-align: left;
# }
# #T_5a343_row0_col0, #T_5a343_row0_col3, #T_5a343_row0_col4, #T_5a343_row0_col5, #T_5a343_row0_col6, #T_5a343_row0_col7, #T_5a343_row1_col0, #T_5a343_row1_col1, #T_5a343_row1_col2, #T_5a343_row1_col3, #T_5a343_row1_col5, #T_5a343_row1_col6, #T_5a343_row1_col7, #T_5a343_row2_col0, #T_5a343_row2_col1, #T_5a343_row2_col2, #T_5a343_row2_col3, #T_5a343_row2_col4, #T_5a343_row2_col5, #T_5a343_row2_col6, #T_5a343_row2_col7, #T_5a343_row3_col0, #T_5a343_row3_col1, #T_5a343_row3_col2, #T_5a343_row3_col3, #T_5a343_row3_col4, #T_5a343_row3_col5, #T_5a343_row3_col6, #T_5a343_row3_col7, #T_5a343_row4_col0, #T_5a343_row4_col1, #T_5a343_row4_col2, #T_5a343_row4_col3, #T_5a343_row4_col4, #T_5a343_row4_col5, #T_5a343_row4_col6, #T_5a343_row4_col7, #T_5a343_row5_col0, #T_5a343_row5_col1, #T_5a343_row5_col2, #T_5a343_row5_col3, #T_5a343_row5_col4, #T_5a343_row5_col5, #T_5a343_row5_col6, #T_5a343_row5_col7, #T_5a343_row6_col0, #T_5a343_row6_col1, #T_5a343_row6_col2, #T_5a343_row6_col3, #T_5a343_row6_col4, #T_5a343_row6_col5, #T_5a343_row6_col6, #T_5a343_row6_col7, #T_5a343_row7_col0, #T_5a343_row7_col1, #T_5a343_row7_col2, #T_5a343_row7_col3, #T_5a343_row7_col4, #T_5a343_row7_col5, #T_5a343_row7_col6, #T_5a343_row7_col7, #T_5a343_row8_col0, #T_5a343_row8_col1, #T_5a343_row8_col2, #T_5a343_row8_col3, #T_5a343_row8_col4, #T_5a343_row8_col5, #T_5a343_row9_col0, #T_5a343_row9_col1, #T_5a343_row9_col2, #T_5a343_row9_col3, #T_5a343_row9_col4, #T_5a343_row9_col5, #T_5a343_row9_col6, #T_5a343_row9_col7, #T_5a343_row10_col0, #T_5a343_row10_col1, #T_5a343_row10_col2, #T_5a343_row10_col3, #T_5a343_row10_col4, #T_5a343_row10_col5, #T_5a343_row10_col6, #T_5a343_row10_col7, #T_5a343_row11_col0, #T_5a343_row11_col1, #T_5a343_row11_col2, #T_5a343_row11_col3, #T_5a343_row11_col4, #T_5a343_row11_col6, #T_5a343_row11_col7, #T_5a343_row12_col0, #T_5a343_row12_col1, #T_5a343_row12_col2, #T_5a343_row12_col3, #T_5a343_row12_col4, #T_5a343_row12_col5, #T_5a343_row12_col6, #T_5a343_row12_col7, #T_5a343_row13_col0, #T_5a343_row13_col1, #T_5a343_row13_col2, #T_5a343_row13_col4, #T_5a343_row13_col5, #T_5a343_row13_col6, #T_5a343_row13_col7 {
#   text-align: left;
# }
# #T_5a343_row0_col1, #T_5a343_row0_col2, #T_5a343_row1_col4, #T_5a343_row8_col6, #T_5a343_row8_col7, #T_5a343_row11_col5, #T_5a343_row13_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_5a343_row0_col8, #T_5a343_row1_col8, #T_5a343_row2_col8, #T_5a343_row3_col8, #T_5a343_row5_col8, #T_5a343_row6_col8, #T_5a343_row7_col8, #T_5a343_row8_col8, #T_5a343_row9_col8, #T_5a343_row10_col8, #T_5a343_row11_col8, #T_5a343_row12_col8, #T_5a343_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_5a343_row4_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_5a343">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5a343_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_5a343_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_5a343_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_5a343_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_5a343_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_5a343_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_5a343_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_5a343_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_5a343_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5a343_level0_row0" class="row_heading level0 row0" >gbc</th>
#       <td id="T_5a343_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_5a343_row0_col1" class="data row0 col1" >0.8875</td>
#       <td id="T_5a343_row0_col2" class="data row0 col2" >0.7127</td>
#       <td id="T_5a343_row0_col3" class="data row0 col3" >0.1330</td>
#       <td id="T_5a343_row0_col4" class="data row0 col4" >0.5377</td>
#       <td id="T_5a343_row0_col5" class="data row0 col5" >0.2127</td>
#       <td id="T_5a343_row0_col6" class="data row0 col6" >0.1758</td>
#       <td id="T_5a343_row0_col7" class="data row0 col7" >0.2268</td>
#       <td id="T_5a343_row0_col8" class="data row0 col8" >0.2760</td>
#     </tr>
#     <tr>
#       <th id="T_5a343_level0_row1" class="row_heading level0 row1" >ada</th>
#       <td id="T_5a343_row1_col0" class="data row1 col0" >Ada Boost Classifier</td>
#       <td id="T_5a343_row1_col1" class="data row1 col1" >0.8872</td>
#       <td id="T_5a343_row1_col2" class="data row1 col2" >0.7063</td>
#       <td id="T_5a343_row1_col3" class="data row1 col3" >0.1100</td>
#       <td id="T_5a343_row1_col4" class="data row1 col4" >0.5770</td>
#       <td id="T_5a343_row1_col5" class="data row1 col5" >0.1816</td>
#       <td id="T_5a343_row1_col6" class="data row1 col6" >0.1501</td>
#       <td id="T_5a343_row1_col7" class="data row1 col7" >0.2131</td>
#       <td id="T_5a343_row1_col8" class="data row1 col8" >0.2340</td>
#     </tr>
#     <tr>
#       <th id="T_5a343_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_5a343_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_5a343_row2_col1" class="data row2 col1" >0.8862</td>
#       <td id="T_5a343_row2_col2" class="data row2 col2" >0.6758</td>
#       <td id="T_5a343_row2_col3" class="data row2 col3" >0.1317</td>
#       <td id="T_5a343_row2_col4" class="data row2 col4" >0.5403</td>
#       <td id="T_5a343_row2_col5" class="data row2 col5" >0.2111</td>
#       <td id="T_5a343_row2_col6" class="data row2 col6" >0.1730</td>
#       <td id="T_5a343_row2_col7" class="data row2 col7" >0.2251</td>
#       <td id="T_5a343_row2_col8" class="data row2 col8" >0.1760</td>
#     </tr>
#     <tr>
#       <th id="T_5a343_level0_row3" class="row_heading level0 row3" >lr</th>
#       <td id="T_5a343_row3_col0" class="data row3 col0" >Logistic Regression</td>
#       <td id="T_5a343_row3_col1" class="data row3 col1" >0.8859</td>
#       <td id="T_5a343_row3_col2" class="data row3 col2" >0.7103</td>
#       <td id="T_5a343_row3_col3" class="data row3 col3" >0.0697</td>
#       <td id="T_5a343_row3_col4" class="data row3 col4" >0.5215</td>
#       <td id="T_5a343_row3_col5" class="data row3 col5" >0.1215</td>
#       <td id="T_5a343_row3_col6" class="data row3 col6" >0.0988</td>
#       <td id="T_5a343_row3_col7" class="data row3 col7" >0.1582</td>
#       <td id="T_5a343_row3_col8" class="data row3 col8" >1.2380</td>
#     </tr>
#     <tr>
#       <th id="T_5a343_level0_row4" class="row_heading level0 row4" >ridge</th>
#       <td id="T_5a343_row4_col0" class="data row4 col0" >Ridge Classifier</td>
#       <td id="T_5a343_row4_col1" class="data row4 col1" >0.8853</td>
#       <td id="T_5a343_row4_col2" class="data row4 col2" >0.7050</td>
#       <td id="T_5a343_row4_col3" class="data row4 col3" >0.0205</td>
#       <td id="T_5a343_row4_col4" class="data row4 col4" >0.5000</td>
#       <td id="T_5a343_row4_col5" class="data row4 col5" >0.0387</td>
#       <td id="T_5a343_row4_col6" class="data row4 col6" >0.0319</td>
#       <td id="T_5a343_row4_col7" class="data row4 col7" >0.0837</td>
#       <td id="T_5a343_row4_col8" class="data row4 col8" >0.0780</td>
#     </tr>
#     <tr>
#       <th id="T_5a343_level0_row5" class="row_heading level0 row5" >dummy</th>
#       <td id="T_5a343_row5_col0" class="data row5 col0" >Dummy Classifier</td>
#       <td id="T_5a343_row5_col1" class="data row5 col1" >0.8846</td>
#       <td id="T_5a343_row5_col2" class="data row5 col2" >0.5000</td>
#       <td id="T_5a343_row5_col3" class="data row5 col3" >0.0000</td>
#       <td id="T_5a343_row5_col4" class="data row5 col4" >0.0000</td>
#       <td id="T_5a343_row5_col5" class="data row5 col5" >0.0000</td>
#       <td id="T_5a343_row5_col6" class="data row5 col6" >0.0000</td>
#       <td id="T_5a343_row5_col7" class="data row5 col7" >0.0000</td>
#       <td id="
# 2025/04/05 15:06:59 INFO mlflow.tracking._tracking_service.client: 🏃 View run model_selection at: http://localhost:5001/#/experiments/4/runs/fb55f00c1cf040928e015a61d1f656c2.
# 2025/04/05 15:06:59 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5001/#/experiments/4.

# %%
final_lr = finalize_model(models_comparison)
# Out:
# 2025/04/05 15:01:24 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/04/05 15:01:25 INFO mlflow.tracking._tracking_service.client: 🏃 View run Gradient Boosting Classifier at: http://localhost:5001/#/experiments/4/runs/edd61dcfe30349089cbd961dcc9ab98b.
# 2025/04/05 15:01:25 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5001/#/experiments/4.

# %%
final_lr
# Out:
# Pipeline(memory=Memory(location=None),
#          steps=[('rare_category_grouping',
#                  TransformerWrapper(exclude=None,
#                                     include=['employment_type',
#                                              'marital_status',
#                                              'education_level',
#                                              'credit_default', 'housing_loan',
#                                              'personal_loan', 'contact_method',
#                                              'previous_campaign_outcome'],
#                                     transformer=RareCategoryGrouping(rare_to_value=0.05,
#                                                                      value='OTHER'))),
#                 ('ordinal_encoding',
#                  Tr...
#                                             criterion='friedman_mse', init=None,
#                                             learning_rate=0.1, loss='log_loss',
#                                             max_depth=3, max_features=None,
#                                             max_leaf_nodes=None,
#                                             min_impurity_decrease=0.0,
#                                             min_samples_leaf=1,
#                                             min_samples_split=2,
#                                             min_weight_fraction_leaf=0.0,
#                                             n_estimators=100,
#                                             n_iter_no_change=None,
#                                             random_state=12, subsample=1.0,
#                                             tol=0.0001, validation_fraction=0.1,
#                                             verbose=0, warm_start=False))],
#          verbose=False)

# %%
lb = get_leaderboard()
# Out:
# Processing:   0%|          | 0/15 [00:00<?, ?it/s]

# %%
lb
# Out:
#                             Model Name  \
# Index
# 0                  Logistic Regression
# 1               K Neighbors Classifier
# 2                          Naive Bayes
# 3             Decision Tree Classifier
# 4                  SVM - Linear Kernel
# 5                     Ridge Classifier
# 6             Random Forest Classifier
# 7      Quadratic Discriminant Analysis
# 8                 Ada Boost Classifier
# 9         Gradient Boosting Classifier
# 10        Linear Discriminant Analysis
# 11              Extra Trees Classifier
# 12     Light Gradient Boosting Machine
# 13                    Dummy Classifier
#
#                                                    Model  Accuracy     AUC  \
# Index
# 0      (TransformerWrapper(exclude=None,\n           ...    0.8859  0.7103
# 1      (TransformerWrapper(exclude=None,\n           ...    0.8761  0.5058
# 2      (TransformerWrapper(exclude=None,\n           ...    0.8170  0.7104
# 3      (TransformerWrapper(exclude=None,\n           ...    0.8044  0.5572
# 4      (TransformerWrapper(exclude=None,\n           ...    0.8331  0.4498
# 5      (TransformerWrapper(exclude=None,\n           ...    0.8853  0.7050
# 6      (TransformerWrapper(exclude=None,\n           ...    0.8843  0.6713
# 7      (TransformerWrapper(exclude=None,\n           ...    0.6760  0.6839
# 8      (TransformerWrapper(exclude=None,\n           ...    0.8872  0.7063
# 9      (TransformerWrapper(exclude=None,\n           ...    0.8875  0.7127
# 10     (TransformerWrapper(exclude=None,\n           ...    0.8748  0.7049
# 11     (TransformerWrapper(exclude=None,\n           ...    0.8679  0.6452
# 12     (TransformerWrapper(exclude=None,\n           ...    0.8862  0.6758
# 13     (TransformerWrapper(exclude=None,\n           ...    0.8846  0.5000
#
#        Recall   Prec.      F1   Kappa     MCC
# Index
# 0      0.0697  0.5215  0.1215  0.0988  0.1582
# 1      0.0059  0.0622  0.0106 -0.0073 -0.0149
# 2      0.3592  0.2862  0.3154  0.2136  0.2162
# 3      0.2359  0.1975  0.2136  0.1033  0.1045
# 4      0.0405  0.0664  0.0501 -0.0250 -0.0286
# 5      0.0205  0.5000  0.0387  0.0319  0.0837
# 6      0.1135  0.5003  0.1835  0.1474  0.1962
# 7      0.5627  0.1943  0.2853  0.1385  0.1733
# 8      0.1100  0.5770  0.1816  0.1501  0.2131
# 9      0.1330  0.5377  0.2127  0.1758  0.2268
# 10     0.2246  0.4294  0.2918  0.2309  0.2471
# 11     0.1333  0.3235  0.1879  0.1295  0.1452
# 12     0.1317  0.5403  0.2111  0.1730  0.2251
# 13     0.0000  0.0000  0.0000  0.0000  0.0000

# %%
lb.iloc[0]['Model']
# Out:
# Pipeline(memory=Memory(location=None),
#          steps=[('rare_category_grouping',
#                  TransformerWrapper(exclude=None,
#                                     include=['employment_type',
#                                              'marital_status',
#                                              'education_level',
#                                              'credit_default', 'housing_loan',
#                                              'personal_loan', 'contact_method',
#                                              'previous_campaign_outcome'],
#                                     transformer=RareCategoryGrouping(rare_to_value=0.05,
#                                                                      value='OTHER'))),
#                 ('ordinal_encoding',
#                  Tr...
#                                                               handle_missing='return_nan',
#                                                               handle_unknown='value',
#                                                               return_df=True,
#                                                               use_cat_names=True,
#                                                               verbose=0))),
#                 ['trained_model',
#                  LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                     fit_intercept=True, intercept_scaling=1,
#                                     l1_ratio=None, max_iter=1000,
#                                     multi_class='auto', n_jobs=None,
#                                     penalty='l2', random_state=12,
#                                     solver='lbfgs', tol=0.0001, verbose=0,
#                                     warm_start=False)]],
#          verbose=False)

# %%
import mlflow
logged_model = 'runs:/4bbca3f2aabd45229479b5d8f7e94664/model'

# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(logged_model)

# Predict on a Pandas DataFrame.
import pandas as pd
loaded_model.predict(pd.DataFrame(data))
# Out:
# Downloading artifacts:   0%|          | 0/5 [00:00<?, ?it/s]
# 2025/04/05 15:13:50 WARNING mlflow.utils.requirements_utils: Detected one or more mismatches between the model's dependencies and the current Python environment:
#  - mlflow (current: 2.16.0, required: mlflow==2.21.2)
# To fix the mismatches, call `mlflow.pyfunc.get_model_dependencies(model_uri)` to fetch the model's environment and install dependencies using the resulting environment file.
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)
